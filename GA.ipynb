# %%
import pandas as pd
import numpy as np
from gurobipy import *
import random
import itertools
import time

# %%
# Parameters
teams = ["Adelaide Crows", 
         "Brisbane Lions", 
         "Carlton Blues", 
         "Collingwood Magpies",
         "Essendon Bombers", 
         "Fremantle Dockers", 
         "Geelong Cats", 
         "Gold Coast Suns",
         "Greater Western Sydney Giants", 
         "Hawthorn Hawks", 
         "Melbourne Demons",
         "North Melbourne Kangaroos", 
         "Port Adelaide Power",
         "Richmond Tigers",
         "St Kilda Saints",
         "Sydney Swans",
         "West Coast Eagles",
         "Western Bulldogs"]

team_numbers = {team: number for number, team in enumerate(sorted(teams), start=0)}

locations = ['VIC','NSW','SA','WA','QLD']

location_numbers = {location: number for number, location in enumerate(sorted(locations), start=0)}

home_locations = ['SA','QLD','VIC','VIC','VIC','WA','VIC','QLD','NSW','VIC',
                          'VIC','VIC','SA','VIC','VIC','NSW','WA','VIC']

ranking = [10,2,5,1,11,14,12,15,7,16,4,17,3,13,6,8,18,9] # 2023 pre-finals rankings

team_fans = [60,45,93,102,79,61,81,20,33,72,68,50,60,100,58,63,100,55] # 2023 number of members, in 000's

wins = [11,17,13.5,18,11,10,10.5,9,13,7,16,3,17,10.5,13,12.5,3,12]

stadiums = ['MCG','Marvel','GMHBA','Adelaide Oval','Optus','Gabba','HBS','SCG','Giants']

stadium_numbers = {stadium: number for number, stadium in enumerate(sorted(stadiums), start=0)}

stadium_locations = ['VIC','VIC','VIC','SA','WA','QLD','QLD','NSW','NSW']

home_stadiums = [['Adelaide Oval'],['Gabba'],['MCG','Marvel'],['MCG','Marvel'],['MCG','Marvel'],['Optus'],['GMHBA'],
                 ['HBS'],['Giants'],['MCG'],['MCG'],['Marvel'],['Adelaide Oval'],
                 ['MCG'],['Marvel'],['SCG'],['Optus'],['Marvel']]

home_location_stadiums = [[] for i in range(len(teams))]
for i in range(len(teams)):
    for j in range(len(stadiums)):
        if stadium_locations[j] == home_locations[i]:
            home_location_stadiums[i].append(stadiums[j])

stadium_size = [100,53,40,54,60,39,27,47,24] # Stadium sizes in 000's

rivals = [['Port Adelaide Power'],
          ['Gold Coast Suns','Collingwood Magpies'], # From wikipedia
          ['Essendon Bombers','Richmond Tigers','Collingwood Magpies', 'Fremantle Dockers'],
          ['Carlton Blues','Essendon Bombers','Brisbane Lions','Melbourne Demons','Richmond Tigers','Geelong Cats',
           'Hawthorn Hawks', 'West Coast Eagles','Port Adelaide Power'],
          ['Carlton Blues','Collingwood Magpies','Richmond Tigers','Hawthorn Hawks','North Melbourne Kangaroos'],
          ['Carlton Blues','West Coast Eagles'],
          ['Collingwood Magpies','Hawthorn Hawks'],
          ['Brisbane Lions'],
          ['Sydney Swans','Western Bulldogs'],
          ['Hawthorn Hawks','Geelong Cats','Essendon Bombers', 'North Melbourne Kangaroos'],
          ['Collingwood Magpies'],
          ['Essendon Bombers','Hawthorn Hawks'],
          ['Adelaide Crows','Collingwood Magpies'],
          ['Carlton Blues','Collingwood Magpies','Essendon Bombers'],
          ['Sydney Swans'],
          ['West Coast Eagles','St Kilda Saints','Greater Western Sydney Giants','Hawthorn Hawks'],
          ['Fremantle Dockers','Sydney Swans','Collingwood Magpies'],
          ['Greater Western Sydney Giants']]

rivals_num = [[team_numbers[i] for i in rivals[j]] for j in range(len(rivals))]

timeslots = [i for i in range(7)]
timeslot_values = [10,13,5,6,11,5,4] # Change later according to attendances
timeslot_names = ['Thursday Night','Friday Night','Saturday Afternoon','Saturday Evening',
                  'Saturday Night','Sunday Afternoon','Sunday Evening']

Ts = range(len(teams))
Ss = range(len(stadiums))
timeslots = range(7)
rounds = range(22)

# Decision Variables
# fixture_matrix = [[[[[0 for i in Ts] for j in Ts] for s in Ss] for t in timeslots] for r in rounds]
fixture_matrix = [[[[[0 for r in rounds] for t in timeslots] for s in Ss] for j in Ts] for i in Ts]

# %%
# # Daniel's Feasibility Function

# def feasibility_print(fixture):
#     violated = 0
#     critical = 0
    
#     for i in Ts: # Each team plays once a week
#         for r in rounds:
#             if sum(fixture[r][t][s][j][i] + fixture[r][t][s][i][j] for j in Ts for s in Ss for t in timeslots)-1 > 0:
#                 print(f'Critical Violation: {teams[i]} does not play in round {r}')
#             critical += abs(sum(fixture[r][t][s][j][i] + fixture[r][t][s][i][j] for j in Ts for s in Ss for t in timeslots)-1)
            
    
#     for i in Ts: # 11 home games 
#         if abs(sum(fixture[r][t][stadium_numbers[s]][j][i] for j in Ts for s in home_stadiums[i] 
#                                  for t in timeslots for r in rounds)-11)>0:
#             print(f'Critical Violation: {teams[i]} play more than 11 home games')
#         critical += abs(sum(fixture[r][t][stadium_numbers[s]][j][i] for j in Ts for s in home_stadiums[i] 
#                                  for t in timeslots for r in rounds)-11)
    
    
#     for i in Ts: # Cannot play yourself 
#         if sum(fixture[r][t][s][i][i] for s in Ss for t in timeslots for r in rounds) > 0:
#             print(f'Critical Violation: {teams[i]} play themselves')
#         critical += sum(fixture[r][t][s][i][i] for s in Ss for t in timeslots for r in rounds)
        
#         for j in Ts: 
#             if i != j:
#                 if max(sum(fixture[r][t][s][j][i] for s in Ss for t in timeslots for r in rounds)-1,0) > 0:
#                     print(f'Violation: Teams {teams[i]} & {teams[j]} verse eachother more than twice')
#                 if max(1-sum(fixture[r][t][s][j][i] + fixture[r][t][s][i][j] for s in Ss for t in timeslots for r in rounds),0)>0:
#                     print(f'Violation: Teams {teams[i]} & {teams[j]} do not verse eachother')
#                 violated += max(sum(fixture[r][t][s][j][i] for s in Ss for t in timeslots for r in rounds)-1,0) #Play more than twice 
#                 violated += max(1-sum(fixture[r][t][s][j][i] + fixture[r][t][s][i][j] for s in Ss for t in timeslots for r in rounds),0) #Play at least once 
                
                
#     for i in Ts: #At least a 5 day break 
#         for r in rounds[:-1]:
#             if max(0,sum(fixture[r][t][s][j][i] + fixture[r][t][s][i][j] for j in Ts for s in Ss for t in [5,6])+ 
#                             sum(fixture[r+1][t][s][j][i]+fixture[r+1][t][s][i][j] for j in Ts for s in Ss for t in [0]) - 1) > 0:
#                 print(f'Violation: Team {teams[i]} does not get a 5 day break in round{r}')
#             violated += max(0,sum(fixture[r][t][s][j][i] + fixture[r][t][s][i][j] for j in Ts for s in Ss for t in [5,6])+ 
#                             sum(fixture[r+1][t][s][j][i]+fixture[r+1][t][s][i][j] for j in Ts for s in Ss for t in [0]) - 1)
            
    
#     # Three games in a row outside home location
#     for i in Ts:
#         for r in rounds[:-2]:
#             if max(0,1-sum(fixture[r_][t][stadium_numbers[s]][i][j]+fixture[r_][t][stadium_numbers[s]][j][i] for j in Ts for s in home_location_stadiums[i] 
#                                  for t in timeslots for r_ in range(r,r+3))) > 0:
#                 print(f'Violation: Team {teams[i]} play more than 3 consecutive games in round {r}')
#             violated += max(0,1-sum(fixture[r_][t][stadium_numbers[s]][i][j]+fixture[r_][t][stadium_numbers[s]][j][i] for j in Ts for s in home_location_stadiums[i] 
#                                  for t in timeslots for r_ in range(r,r+3)))
       
#     # Four away games in a row
#     for i in Ts:
#         for r in rounds[:-3]:
#             if  max(0,1-sum(fixture[r_][t][s][j][i] for j in Ts for s in Ss for t in timeslots for r_ in range(r,r+4)))>1:
#                 print(f'Violation: Team {teams[i]} plays 4 games in a row in round {r}')
#             violated += max(0,1-sum(fixture[r_][t][s][j][i] for j in Ts for s in Ss for t in timeslots for r_ in range(r,r+4)))
    
    
#     # Constraint 7: 2+ games in one day in the same stadium
#     for r in rounds:
#         for s in Ss:
            
#             if max(0,sum(fixture[r][t][s][j][i] for i in Ts for j in Ts for t in [5, 6])-1) > 0:
#                 print(f'Violation: Only 1 Sunday game in round {r}, stadium {s}')
#             if max(0,sum(fixture[r][t][s][j][i] for i in Ts for j in Ts for t in [2, 3, 4])-1)>0:
#                 print(f'Violation: Only 1 Saturday game in round {r}, stadium {s}')
            
#             violated += max(0,sum(fixture[r][t][s][j][i] for i in Ts for j in Ts for t in [5, 6])-1)
            
#             violated += max(0,sum(fixture[r][t][s][j][i] for i in Ts for j in Ts for t in [2, 3, 4])-1)
            
#             for t in [0,1]:
#                 if max(0,sum(fixture[r][t][s][j][i] for i in Ts for j in Ts)-1)>0:
#                     print(f'Violation: Stadium {s} overbooked in timeslot {timeslot_names[i]}')
#                 violated += max(0,sum(fixture[r][t][s][j][i] for i in Ts for j in Ts)-1)
    
    
#     # Constraint: No more than two games in any timeslot, and only one on Thursday and Friday night, at least one in each
#     for r in rounds:
        
#         for t in [2,3,4,5,6]:
#             if max(0,1-sum(fixture[r][t][s][j][i] for i in Ts for j in Ts for s in Ss))>0:
#                 print('Violation: No game in round {r}, timeslot {timeslot_names[i]}')
#             if max(0,sum(fixture[r][t][s][j][i] for i in Ts for j in Ts for s in Ss)-2) > 0:
#                 print(f'Violation: More than 2 simultaneous games in round {r}, timeslot {timeslot_names[i]}')
#             violated += max(0,1-sum(fixture[r][t][s][j][i] for i in Ts for j in Ts for s in Ss)) # At least one game each timeslot
#             violated += max(0,sum(fixture[r][t][s][j][i] for i in Ts for j in Ts for s in Ss)-2)
        
#         # Why seperate thurs and fri 
#         for t in [0,1]:
#             if max(0,sum(fixture[r][t][s][j][i] for i in Ts for j in Ts for s in Ss)-1)>0:
#                 print(f'Violation: More than one game in round {r}, timeslot {timeslot_names[i]}')        
#             violated += max(0,sum(fixture[r][t][s][j][i] for i in Ts for j in Ts for s in Ss)-1) # One game 
            
            
#     return violated, critical

# %%
# Daniel's Feasibility Function

# def feasibility(fixture):
#     violated = 0
#     critical = 0
    
#     for i in Ts: # Each team plays once a week
#         for r in rounds:
#             critical += abs(sum(fixture[r][t][s][j][i] + fixture[r][t][s][i][j] for j in Ts for s in Ss for t in timeslots)-1)
            
    
#     for i in Ts:
#         critical += abs(sum(fixture[r][t][stadium_numbers[s]][j][i] for j in Ts for s in home_stadiums[i] 
#                                  for t in timeslots for r in rounds)-11)
    
    
#     for i in Ts:
#         critical += sum(fixture[r][t][s][i][i] for s in Ss for t in timeslots for r in rounds)
        
#         for j in Ts:
#             if i != j:
#                 violated += max(sum(fixture[r][t][s][j][i] for s in Ss for t in timeslots for r in rounds)-1,0)
#                 violated += max(1-sum(fixture[r][t][s][j][i] + fixture[r][t][s][i][j] for s in Ss for t in timeslots for r in rounds),0)
                
                
#     for i in Ts:
#         for r in rounds[:-1]:
#             violated += max(0,sum(fixture[r][t][s][j][i] + fixture[r][t][s][i][j] for j in Ts for s in Ss for t in [5,6])+ 
#                             sum(fixture[r+1][t][s][j][i]+fixture[r+1][t][s][i][j] for j in Ts for s in Ss for t in [0]) - 1)
            
    
#     # Three games in a row outside home location
#     for i in Ts:
#         for r in rounds[:-2]:
#             violated += max(0,1-sum(fixture[r_][t][stadium_numbers[s]][i][j]+fixture[r_][t][stadium_numbers[s]][j][i] for j in Ts for s in home_location_stadiums[i] 
#                                  for t in timeslots for r_ in range(r,r+3)))
       
#     # Four away games in a row
#     for i in Ts:
#         for r in rounds[:-3]:
#             violated += max(0,1-sum(fixture[r_][t][s][j][i] for j in Ts for s in Ss for t in timeslots for r_ in range(r,r+4)))
    
    
#     # Constraint 7: 2+ games in one day in the same stadium
#     for r in rounds:
#         for s in Ss:
            
#             violated += max(0,sum(fixture[r][t][s][j][i] for i in Ts for j in Ts for t in [5, 6])-1)
            
#             violated += max(0,sum(fixture[r][t][s][j][i] for i in Ts for j in Ts for t in [2, 3, 4])-1)
            
#             for t in [0,1]:
#                 violated += max(0,sum(fixture[r][t][s][j][i] for i in Ts for j in Ts)-1)
    
    
#     # Constraint: No more than two games in any timeslot, and only one on Thursday and Friday night, at least one in each
#     for r in rounds:
        
#         for t in [2,3,4,5,6]:
#             violated += max(0,1-sum(fixture[r][t][s][j][i] for i in Ts for j in Ts for s in Ss)) # At least one game each timeslot
#             violated += max(0,sum(fixture[r][t][s][j][i] for i in Ts for j in Ts for s in Ss)-2)
        
#         for t in [0,1]:
#             #Changed this from 'abs' to 'max'
#             violated += max(0,sum(fixture[r][t][s][j][i] for i in Ts for j in Ts for s in Ss)-1) # One game
            
            
#     return violated, critical

# %%
def feasibility(fixture):
    violated = 0
    critical = 0
    
    for i in Ts: # Each team plays once a week
        for r in rounds:
            critical += abs(sum(fixture[i][j][s][t][r] + fixture[j][i][s][t][r] for j in Ts for s in Ss for t in timeslots)-1)
            
    
    for i in Ts:
        critical += abs(sum(fixture[i][j][stadium_numbers[s]][t][r] for j in Ts for s in home_stadiums[i] 
                                 for t in timeslots for r in rounds)-11)
    
    
    for i in Ts:
        critical += sum(fixture[i, i, s, t, r] for s in Ss for t in timeslots for r in rounds)
        
        for j in Ts:
            if i != j:
                violated += max(sum(fixture[i][j][s][t][r] for s in Ss for t in timeslots for r in rounds)-1,0)
                violated += max(1-sum(fixture[i][j][s][t][r] + fixture[j][i][s][t][r] for s in Ss for t in timeslots for r in rounds),0)
                
                
    for i in Ts:
        for r in rounds[:-1]:
            violated += max(0,sum(fixture[i][j][s][t][r] + fixture[j][i][s][t][r] for j in Ts for s in Ss for t in [5,6])+ 
                            sum(fixture[i, j, s, t, r+1]+fixture[j, i, s, t, r+1] for j in Ts for s in Ss for t in [0]) - 1)
            
    
    # Three games in a row outside home location
    for i in Ts:
        for r in rounds[:-2]:
            violated += max(0,1-sum(fixture[j][i][stadium_numbers[s]][t][r_]+fixture[i][j][stadium_numbers[s]][t][r_] for j in Ts for s in home_location_stadiums[i] 
                                 for t in timeslots for r_ in range(r,r+3)))
       
    # Four away games in a row
    for i in Ts:
        for r in rounds[:-3]:
            violated += max(0,1-sum(fixture[i, j, s, t, r_] for j in Ts for s in Ss for t in timeslots for r_ in range(r,r+4)))
    
    
    # Constraint 7: 2+ games in one day in the same stadium
    for r in rounds:
        for s in Ss:
            
            violated += max(0,sum(fixture[i][j][s][t][r] for i in Ts for j in Ts for t in [5, 6])-1)
            
            violated += max(0,sum(fixture[i][j][s][t][r] for i in Ts for j in Ts for t in [2, 3, 4])-1)
            
            for t in [0,1]:
                violated += max(0,sum(fixture[i][j][s][t][r] for i in Ts for j in Ts)-1)
    
    
    # Constraint: No more than two games in any timeslot, and only one on Thursday and Friday night, at least one in each
    for r in rounds:
        
        for t in [2,3,4,5,6]:
            violated += max(0,1-sum(fixture[i][j][s][t][r] for i in Ts for j in Ts for s in Ss)) # At least one game each timeslot
            violated += max(0,sum(fixture[i][j][s][t][r] for i in Ts for j in Ts for s in Ss)-2)
        
        for t in [0,1]:
            violated += max(0,sum(fixture[i][j][s][t][r] for i in Ts for j in Ts for s in Ss)-1) # One game
            
            
    return violated, critical

# %%
# Attractiveness Function Parameters, adjust them as needed
alpha = 1.0
beta = 1.0
gamma = 1.0
sigma = 1.0
xi = 1.0

def attractiveness(i, j, s, t, r):
    score = 1
    if r == 0:
        score *= 4
    elif r == 1:
        score *= 2
    elif r == 21:
        score *= 1.5
    
    if j in [team_numbers[i] for i in rivals[0]]:
        score *= 1+alpha
    
    score /= np.sqrt(1+abs(ranking[i]-ranking[j]))
    score  /= np.sqrt(ranking[i]+ranking[j])
    
    if stadium_locations[s] == home_locations[j]:
        score *= (1+beta)
        
    score *= np.sqrt(stadium_size[s])
    score *= (team_fans[i]+0.5*team_fans[j])
    
    score *= timeslot_values[t]
    
    return score

# %%
def probability_win(i, j, s):
    probability = wins[i]/(wins[i]+wins[j])
    if stadiums[s] not in home_location_stadiums[j]:
        probability += (1-probability)/2.5
    elif stadiums[s] not in home_stadiums[j]:
        probability += (1-probability)/4
    else:
        probability += (1-probability)/10
        
    return probability

# %%
# def expected_win_variance(fixture):
#     results = []
#     expected_wins = [0]*18
#     for r in rounds:
#         for i in Ts:
#             for j in Ts:
#                 for s in Ss:
#                     for t in timeslots:
#                         expected_wins[i] += probability_win(i, j, s)*fixture[r][t][s][j][i]
#                         expected_wins[i] += (1-probability_win(j, i, s))*fixture[r][t][s][i][j]
        
#         results.append(np.var(expected_wins))
    
#     # print(results)
#     return sum((i+1)*results[i] for i in range(len(results)))

# %%
def fixture_attractiveness(fixture,max_value,violated_factor,critical_factor,equality_factor):
    total_score = 0
    
    for r in rounds:
        for t in timeslots:
            value = 0
            for i in Ts:
                for j in Ts:
                    for s in Ss:
                        value += attractiveness(i, j, s, t, r)*fixture[i][j][s][t][r]
                            
            total_score += min(max_value,value)
            
    violated, critical = feasibility(fixture)
    equality = equality_factor*expected_win_variance(fixture)
    
    return total_score - violated_factor*violated - critical_factor*critical - equality

# %%
# def expected_win_variance(fixture):
#     results = []
#     expected_wins = [0]*18
#     for r in rounds:
#         for i in Ts:
#             for j in Ts:
#                 for s in Ss:
#                     for t in timeslots:
#                         expected_wins[i] += probability_win(i, j, s)*fixture[r][t][s][j][i]
#                         expected_wins[i] += (1-probability_win(j, i, s))*fixture[r][t][s][i][j]
        
#         results.append(np.var(expected_wins))
    
#     # print(results)
#     return sum((i+1)*results[i] for i in range(len(results)))

# %%
# def fixture_attractiveness(fixture,max_value,violated_factor,critical_factor,equality_factor):
#     total_score = 0
    
#     for r in rounds:
#         for t in timeslots:
#             value = 0
#             for i in Ts:
#                 for j in Ts:
#                     for s in Ss:
#                         value += attractiveness(i, j, s, t, r)*fixture[r][t][s][j][i]
            
#             total_score += min(max_value,value)

#     violated, critical = feasibility(fixture)
#     equality = equality_factor*expected_win_variance(fixture)

#     # print(total_score)
#     # print('-', violated_factor*violated)
#     # print('-', critical_factor*critical)
#     # print('-', equality)
    
#     return total_score - violated_factor*violated - critical_factor*critical - equality

# %%
def objective_value(fixture):

    violated, critical = feasibility(fixture)

    violated_penalty = 2*10^4
    critical_penalty = 10^6
    # for i in Ts:
    #     for j in Ts:
    #         for s in Ss:
    #             for r in rounds:
    #                 for t in timeslots:
    #                     print(attractiveness(i,j,s,t,r))

    objective_value = - violated_penalty*violated - critical_penalty*critical + fixture_attractiveness(fixture, 2*10^4, critical_penalty, violated_penalty, 10^3) 

    return objective_value

# %%
import pickle as pkl 

def genesis(pop_size=2):
    print('Genesis')

    # MIP SOLUTION
    with open('solutions/MILP_Fixture_1000.pkl', 'rb') as pkl_file:
        MIP_soln1 = pkl.load(pkl_file)
    with open('solutions/MILP_Fixture_10000.pkl', 'rb') as pkl_file:
        MIP_soln2 = pkl.load(pkl_file)
    with open('solutions/MILP_Fixture_100000.pkl', 'rb') as pkl_file:
        MIP_soln3 = pkl.load(pkl_file)
    with open('solutions/MILP_Fixture_1000000.pkl', 'rb') as pkl_file:
        MIP_soln4 = pkl.load(pkl_file)

    MIP_solns = [MIP_soln1, MIP_soln2, MIP_soln3, MIP_soln4]
    
    pop = []
    for soln in MIP_solns:
        pop.append([soln, objective_value(soln)])

    # for i in range(pop_size-1):
    #     fixture_matrix = [[[[[0 for i in Ts] for j in Ts] for s in Ss] for t in timeslots] for r in rounds]   
    #     for r in rounds: 
    #         available_timeslots = list(timeslots)
    #         available_multiple_game_timeslots = [2,3,4,5,6]    
    #         for game in range(9):
    #             # Randomly choose two teams. Ensure there is at least one rivalry match. 
    #             if game == 0:
    #                 selection_i = random.choice(Ts)
    #                 selection_j = random.choice(rivals_num[selection_i])
    #                 selection_stadium = random.choice(home_location_stadiums[selection_i])
    #                 selection_stadium = stadium_numbers[selection_stadium]
    #                 if len(available_timeslots) > 0:  
    #                     t = random.choice(available_timeslots)
    #                     available_timeslots.remove(t)
    #                 else: 
    #                     t = random.choice(available_multiple_game_timeslots)
    #                     available_multiple_game_timeslots.remove(t)
    #                 fixture_matrix[r][t][selection_stadium][selection_j][selection_i] = 1 
    #                 # print('Rivalry Round: ', teams[selection_i], ' vs. ', teams[selection_j])
    #             else: 
    #                 team_pairing = random.sample(Ts, 2)
    #                 selection_i = team_pairing[0]
    #                 selection_j = team_pairing[1]
    #                 selection_stadium = random.choice(home_location_stadiums[selection_i])
    #                 selection_stadium = stadium_numbers[selection_stadium]
    #                 if len(available_timeslots) > 0:  
    #                     t = random.choice(available_timeslots)
    #                     available_timeslots.remove(t)
    #                 else: 
    #                     t = random.choice(available_multiple_game_timeslots)
    #                     available_multiple_game_timeslots.remove(t)
    #                 fixture_matrix[r][t][selection_stadium][selection_j][selection_i] = 1 
    #                 # print(teams[selection_i], ' vs. ', teams[selection_j])    
    #         # print('\n')  
    #     pop.append([fixture_matrix, objective_value(fixture_matrix)])
    return pop

genesis()
# Out:
# Genesis
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19132/2914652701.py in <module>
#      58     return pop
#      59
# ---> 60 genesis()
#
# ~\AppData\Local\Temp/ipykernel_19132/2914652701.py in genesis(pop_size)
#      18     pop = []
#      19     for soln in MIP_solns:
# ---> 20         pop.append([soln, objective_value(soln)])
#      21
#      22     # for i in range(pop_size-1):
#
# ~\AppData\Local\Temp/ipykernel_19132/1679851589.py in objective_value(fixture)
#      12     #                     print(attractiveness(i,j,s,t,r))
#      13
# ---> 14     objective_value = - violated_penalty*violated - critical_penalty*critical + fixture_attractiveness(fixture, 2*10^4, critical_penalty, violated_penalty, 10^3)
#      15
#      16     return objective_value
#
# ~\AppData\Local\Temp/ipykernel_19132/2828877369.py in fixture_attractiveness(fixture, max_value, violated_factor, critical_factor, equality_factor)
#      13
#      14     violated, critical = feasibility(fixture)
# ---> 15     equality = equality_factor*expected_win_variance(fixture)
#      16
#      17     return total_score - violated_factor*violated - critical_factor*critical - equality
#
# ~\AppData\Local\Temp/ipykernel_19132/2772993551.py in expected_win_variance(fixture)
#       7                 for s in Ss:
#       8                     for t in timeslots:
# ----> 9                         expected_wins[i] += probability_win(i, j, s)*fixture[r][t][s][j][i]
#      10                         expected_wins[i] += (1-probability_win(j, i, s))*fixture[r][t][s][i][j]
#      11
#
# IndexError: index 7 is out of bounds for axis 0 with size 7

# %%
import random

def select_parents(population):
    """
    Select two individuals from a population for reproduction.
    
    Args:
    - population (list): A list of individuals, where each individual is represented as a tuple (individual_data, objective_value).
    
    Returns:
    - parent1 (tuple): The first parent selected.
    - parent2 (tuple): The second parent selected.
    """
    
    print('Romance')
    # Sort the population by objective value in descending order (higher is better)
    sorted_population = sorted(population, key=lambda x: x[1], reverse=True)

    # Calculate the number of elite individuals (top 25%)
    num_elite = len(sorted_population) // 4

    if num_elite > 1:
        # If there are enough elite individuals, select the first parent as an elite individual
        parent1 = random.choice(sorted_population[:num_elite])
    else:
        # If there are not enough elite individuals, choose both parents randomly
        parent1 = random.choice(sorted_population)
    
    # Select the second parent randomly from the entire population
    parent2 = random.choice(population)

    return parent1, parent2

# %%
def get_dimensions(lst):
    dimensions = []

    while isinstance(lst, list):
        dimensions.append(len(lst))
        lst = lst[0] if len(lst) > 0 else None

    return dimensions

# %%
def birth(parent1, parent2):
    print('Birth')
    # print(get_dimensions(parent1), get_dimensions(parent2))
    # Determine a random crossover point
    crossover_point = np.random.randint(0, len(parent1))  # Include 0, exclude len(parent1)

    # Create the first child by combining the first part of parent1 and the second part of parent2
    child1 = np.concatenate((parent1[:crossover_point], parent2[crossover_point:]))

    # Create the second child by combining the first part of parent2 and the second part of parent1
    child2 = np.concatenate((parent2[:crossover_point], parent1[crossover_point:]))

    return [child1, objective_value(child1)], [child2, objective_value(child2)]

# %%
def evolutionPlus():

    start_time = time.time()  # Record the start time

    # Parameters 
    pop_size = 5  # Adjust as needed
    solns = []
    num_gen = 0
    duration = 60 * 10

    pop = genesis(pop_size)  # Use the provided pop_size when calling genesis

    best_soln = max(pop, key=lambda x: x[1])
    while time.time() - start_time < duration:
        num_gen += 1
        # Select Parents
        parent1, parent2 = select_parents(pop)

        # Create Children
        child1, child2 = birth(parent1[0], parent2[0])
        pop.append(child1)
        pop.append(child2)
        
        # Death
        family = [parent1, parent2, child1, child2]
        # Find family member with the minimum objective value
        min_value = 1000000000000
        to_die_idx = None
        for i, member in enumerate(family):
            if member[1] < min_value:
                min_value = member[1]
                to_die_idx = i

        # Remove the element at to_die_idx
        if to_die_idx is not None:
            print('Death')
            pop.pop(to_die_idx)

        # Occassionally perform local optimisation

        # Occasionally perform immigration

        # Find the index of the element with the largest objective value
        max_index = 0
        max_value = pop[0][1]
        for i, soln in enumerate(pop):
            if soln[1] > max_value:
                max_value = soln[1]
                max_index = i

        # Extract the element with the largest objective value 
        best_soln = pop[max_index]
        solns.append(best_soln)

    for i, soln in enumerate(pop):
        if soln[1] > max_value:
            max_index = i
    best_soln = pop[max_index]

    print('Solution: ', best_soln[0])
    print('Value: ', best_soln[1])

    return best_soln

# %%
best_soln = evolutionPlus()
# Out:
# Genesis
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19132/2039287063.py in <module>
# ----> 1 best_soln = evolutionPlus()
#
# ~\AppData\Local\Temp/ipykernel_19132/455618266.py in evolutionPlus()
#       9     duration = 60 * 10
#      10
# ---> 11     pop = genesis(pop_size)  # Use the provided pop_size when calling genesis
#      12
#      13     best_soln = max(pop, key=lambda x: x[1])
#
# ~\AppData\Local\Temp/ipykernel_19132/1020934869.py in genesis(pop_size)
#      18     pop = []
#      19     for soln in MIP_solns:
# ---> 20         pop.append([soln, objective_value(soln)])
#      21
#      22     # for i in range(pop_size-1):
#
# ~\AppData\Local\Temp/ipykernel_19132/1679851589.py in objective_value(fixture)
#       1 def objective_value(fixture):
#       2
# ----> 3     violated, critical = feasibility(fixture)
#       4
#       5     violated_penalty = 2*10^4
#
# ~\AppData\Local\Temp/ipykernel_19132/4059229162.py in feasibility(fixture)
#       7     for i in Ts: # Each team plays once a week
#       8         for r in rounds:
# ----> 9             critical += abs(sum(fixture[r][t][s][j][i] + fixture[r][t][s][i][j] for j in Ts for s in Ss for t in timeslots)-1)
#      10
#      11
#
# ~\AppData\Local\Temp/ipykernel_19132/4059229162.py in <genexpr>(.0)
#       7     for i in Ts: # Each team plays once a week
#       8         for r in rounds:
# ----> 9             critical += abs(sum(fixture[r][t][s][j][i] + fixture[r][t][s][i][j] for j in Ts for s in Ss for t in timeslots)-1)
#      10
#      11
#
# IndexError: index 7 is out of bounds for axis 0 with size 7

# %%
feasibility_print(best_soln[0])
# Out:
# Critical Violation: Collingwood Magpies does not play in round 11
# Critical Violation: Collingwood Magpies does not play in round 12
# Critical Violation: Collingwood Magpies does not play in round 13
# Critical Violation: Essendon Bombers does not play in round 12
# Critical Violation: Geelong Cats does not play in round 12
# Critical Violation: Gold Coast Suns does not play in round 12
# Critical Violation: Hawthorn Hawks does not play in round 11
# Critical Violation: Hawthorn Hawks does not play in round 12
# Critical Violation: Melbourne Demons does not play in round 11
# Critical Violation: North Melbourne Kangaroos does not play in round 12
# Critical Violation: North Melbourne Kangaroos does not play in round 13
# Critical Violation: Richmond Tigers does not play in round 13
# Critical Violation: St Kilda Saints does not play in round 11
# Critical Violation: Sydney Swans does not play in round 12
# Critical Violation: Sydney Swans does not play in round 13
# Critical Violation: Adelaide Crows play more than 11 home games
# Critical Violation: Brisbane Lions play more than 11 home games
# Critical Violation: Collingwood Magpies play more than 11 home games
# Critical Violation: Essendon Bombers play more than 11 home games
# Critical Violation: Fremantle Dockers play more than 11 home games
# Critical Violation: Geelong Cats play more than 11 home games
# Critical Violation: Hawthorn Hawks play more than 11 home games
# Critical Violation: Melbourne Demons play more than 11 home games
# Critical Violation: North Melbourne Kangaroos play more than 11 home games
# Critical Violation: Richmond Tigers play more than 11 home games
# Critical Violation: Sydney Swans play more than 11 home games
# Critical Violation: Western Bulldogs play more than 11 home games
# Violation: Teams Adelaide Crows & Brisbane Lions do not verse eachother
# Violation: Teams Adelaide Crows & Essendon Bombers verse eachother more than twice
# Violation: Teams Adelaide Crows & Geelong Cats verse eachother more than twice
# Violation: Teams Adelaide Crows & North Melbourne Kangaroos do not verse eachother
# Violation: Teams Adelaide Crows & Richmond Tigers verse eachother more than twice
# Violation: Teams Adelaide Crows & St Kilda Saints do not verse eachother
# Violation: Teams Adelaide Crows & Western Bulldogs verse eachother more than twice
# Violation: Teams Brisbane Lions & Adelaide Crows do not verse eachother
# Violation: Teams Brisbane Lions & Collingwood Magpies verse eachother more than twice
# Violation: Teams Brisbane Lions & Melbourne Demons verse eachother more than twice
# Violation: Teams Brisbane Lions & St Kilda Saints verse eachother more than twice
# Violation: Teams Brisbane Lions & West Coast Eagles do not verse eachother
# Violation: Teams Carlton Blues & Essendon Bombers do not verse eachother
# Violation: Teams Carlton Blues & St Kilda Saints verse eachother more than twice
# Violation: Teams Collingwood Magpies & Gold Coast Suns do not verse eachother
# Violation: Teams Collingwood Magpies & Melbourne Demons verse eachother more than twice
# Violation: Teams Essendon Bombers & Carlton Blues do not verse eachother
# Violation: Teams Essendon Bombers & Sydney Swans verse eachother more than twice
# Violation: Teams Essendon Bombers & West Coast Eagles do not verse eachother
# Violation: Teams Essendon Bombers & Western Bulldogs verse eachother more than twice
# Violation: Teams Fremantle Dockers & Hawthorn Hawks verse eachother more than twice
# Violation: Teams Fremantle Dockers & St Kilda Saints do not verse eachother
# Violation: Teams Fremantle Dockers & Western Bulldogs do not verse eachother
# Violation: Teams Geelong Cats & Collingwood Magpies verse eachother more than twice
# Violation: Teams Geelong Cats & Gold Coast Suns do not verse eachother
# Violation: Teams Geelong Cats & Hawthorn Hawks verse eachother more than twice
# Violation: Teams Geelong Cats & Port Adelaide Power do not verse eachother
# Violation: Teams Geelong Cats & Richmond Tigers verse eachother more than twice
# Violation: Teams Geelong Cats & Western Bulldogs verse eachother more than twice
# Violation: Teams Gold Coast Suns & Collingwood Magpies do not verse eachother
# Violation: Teams Gold Coast Suns & Fremantle Dockers verse eachother more than twice
# Violation: Teams Gold Coast Suns & Geelong Cats do not verse eachother
# Violation: Teams Gold Coast Suns & North Melbourne Kangaroos verse eachother more than twice
# Violation: Teams Gold Coast Suns & Sydney Swans do not verse eachother
# Violation: Teams Gold Coast Suns & West Coast Eagles verse eachother more than twice
# Violation: Teams Greater Western Sydney Giants & Adelaide Crows verse eachother more than twice
# Violation: Teams Greater Western Sydney Giants & St Kilda Saints verse eachother more than twice
# Violation: Teams Hawthorn Hawks & Gold Coast Suns verse eachother more than twice
# Violation: Teams Hawthorn Hawks & North Melbourne Kangaroos verse eachother more than twice
# Violation: Teams Hawthorn Hawks & Port Adelaide Power do not verse eachother
# Violation: Teams Melbourne Demons & Fremantle Dockers verse eachother more than twice
# Violation: Teams Melbourne Demons & Richmond Tigers do not verse eachother
# Violation: Teams North Melbourne Kangaroos & Adelaide Crows do not verse eachother
# Violation: Teams North Melbourne Kangaroos & Fremantle Dockers verse eachother more than twice
# Violation: Teams Port Adelaide Power & Brisbane Lions verse eachother more than twice
# Violation: Teams Port Adelaide Power & Carlton Blues verse eachother more than twice
# Violation: Teams Port Adelaide Power & Collingwood Magpies verse eachother more than twice
# Violation: Teams Port Adelaide Power & Geelong Cats do not verse eachother
# Violation: Teams Port Adelaide Power & Hawthorn Hawks do not verse eachother
# Violation: Teams Port Adelaide Power & St Kilda Saints verse eachother more than twice
# Violation: Teams Richmond Tigers & Essendon Bombers verse eachother more than twice
# Violation: Teams Richmond Tigers & Gold Coast Suns verse eachother more than twice
# Violation: Teams Richmond Tigers & Melbourne Demons do not verse eachother
# Violation: Teams St Kilda Saints & Adelaide Crows do not verse eachother
# Violation: Teams St Kilda Saints & Collingwood Magpies verse eachother more than twice
# Violation: Teams St Kilda Saints & Fremantle Dockers do not verse eachother
# Violation: Teams St Kilda Saints & Gold Coast Suns verse eachother more than twice
# Violation: Teams St Kilda Saints & North Melbourne Kangaroos verse eachother more than twice
# Violation: Teams Sydney Swans & Geelong Cats verse eachother more than twice
# Violation: Teams Sydney Swans & Gold Coast Suns do not verse eachother
# Violation: Teams Sydney Swans & Hawthorn Hawks verse eachother more than twice
# Violation: Teams Sydney Swans & North Melbourne Kangaroos verse eachother more than twice
# Violation: Teams West Coast Eagles & Brisbane Lions do not verse eachother
# Violation: Teams West Coast Eagles & Essendon Bombers do not verse eachother
# Violation: Teams West Coast Eagles & North Melbourne Kangaroos verse eachother more than twice
# Violation: Teams West Coast Eagles & Sydney Swans verse eachother more than twice
# Violation: Teams Western Bulldogs & Fremantle Dockers do not verse eachother
# Violation: Teams Western Bulldogs & Hawthorn Hawks verse eachother more than twice
# Violation: Team North Melbourne Kangaroos does not get a 5 day break in round12
# Violation: Team Adelaide Crows play more than 3 consecutive games in round 11
# Violation: Team Brisbane Lions play more than 3 consecutive games in round 11
# Violation: Team Brisbane Lions play more than 3 consecutive games in round 12
# Violation: Team Carlton Blues play more than 3 consecutive games in round 10
# Violation: Team Fremantle Dockers play more than 3 consecutive games in round 11
# Violation: Team Richmond Tigers play more than 3 consecutive games in round 10
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_424/4041231735.py in <module>
# ----> 1 feasibility_print(best_soln[0])
#
# ~\AppData\Local\Temp/ipykernel_424/1801686170.py in feasibility_print(fixture)
#      76             for t in [0,1]:
#      77                 if max(0,sum(fixture[r][t][s][j][i] for i in Ts for j in Ts)-1)>0:
# ---> 78                     print(f'Violation: Stadium {s} overbooked in timeslot {timeslot_names[i]}')
#      79                 violated += max(0,sum(fixture[r][t][s][j][i] for i in Ts for j in Ts)-1)
#      80
#
# IndexError: list index out of range

# %%
best_fixture = best_soln[0]
for r in rounds: 
    print('\nRound ', r)
    for t in timeslots:
        for i in Ts:
            for j in Ts:
                for s in range(len(Ss)-1):
                    if best_fixture[r][t][s][j][i] == 1:
                        if j in [team_numbers[rival] for rival in rivals[i]]:
                            print("Rivalry Match! ", teams[i], " VS ", teams[j], ' AT ', stadiums[s], ' ON ', timeslot_names[t])
                        else: 
                            print(teams[i], " VS ", teams[j], ' AT ', stadiums[s], ' ON ', timeslot_names[t])
# Out:
# Round  0
# Rivalry Match!  Port Adelaide Power  VS  Collingwood Magpies  AT  MCG  ON  Thursday Night
# Rivalry Match!  Brisbane Lions  VS  Collingwood Magpies  AT  Optus  ON  Friday Night
# Sydney Swans  VS  Geelong Cats  AT  Adelaide Oval  ON  Saturday Afternoon
# Gold Coast Suns  VS  Adelaide Crows  AT  Optus  ON  Saturday Evening
# Hawthorn Hawks  VS  Greater Western Sydney Giants  AT  Marvel  ON  Saturday Evening
# Western Bulldogs  VS  Fremantle Dockers  AT  HBS  ON  Saturday Night
# Rivalry Match!  Essendon Bombers  VS  Richmond Tigers  AT  Marvel  ON  Sunday Afternoon
# Rivalry Match!  Brisbane Lions  VS  Collingwood Magpies  AT  Optus  ON  Sunday Evening
# Western Bulldogs  VS  Richmond Tigers  AT  Gabba  ON  Sunday Evening
#
# Round  1
# Sydney Swans  VS  Essendon Bombers  AT  Adelaide Oval  ON  Thursday Night
# Rivalry Match!  Port Adelaide Power  VS  Collingwood Magpies  AT  MCG  ON  Friday Night
# Fremantle Dockers  VS  North Melbourne Kangaroos  AT  SCG  ON  Saturday Afternoon
# Adelaide Crows  VS  Collingwood Magpies  AT  MCG  ON  Saturday Evening
# Hawthorn Hawks  VS  Carlton Blues  AT  Gabba  ON  Saturday Night
# Hawthorn Hawks  VS  Carlton Blues  AT  HBS  ON  Saturday Night
# Essendon Bombers  VS  Geelong Cats  AT  Marvel  ON  Sunday Afternoon
# Gold Coast Suns  VS  St Kilda Saints  AT  GMHBA  ON  Sunday Evening
# West Coast Eagles  VS  Essendon Bombers  AT  SCG  ON  Sunday Evening
#
# Round  2
# Gold Coast Suns  VS  Richmond Tigers  AT  GMHBA  ON  Thursday Night
# Fremantle Dockers  VS  Collingwood Magpies  AT  SCG  ON  Friday Night
# Rivalry Match!  West Coast Eagles  VS  Sydney Swans  AT  SCG  ON  Saturday Afternoon
# Geelong Cats  VS  Western Bulldogs  AT  Marvel  ON  Saturday Evening
# Melbourne Demons  VS  Hawthorn Hawks  AT  Marvel  ON  Saturday Night
